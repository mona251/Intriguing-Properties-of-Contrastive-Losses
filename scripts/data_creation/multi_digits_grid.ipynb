# %% [markdown]
# # Visualization of a grid of a minst digit over a canvas

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import importlib
import src.data_generation
from src.data_generation.Dataset import Dataset

importlib.reload(src.data_generation.Dataset)
from src.data_generation.Dataset import Dataset

# %%
dataset = Dataset()
multi_digits_grid_images = dataset.generate_multi_digits_grid(
    n_images=4, n_repetition_digit_img=12, n_cells_in_grid=16,
    img_shape=(112, 112), repeat_same_digit=False)
for img in multi_digits_grid_images:
    plt.imshow(img)
    plt.show()
